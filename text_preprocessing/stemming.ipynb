# %%
words = ["eating", "eats", "eaten", "writing", "writes", "programming", "programs", "history", "finally", "finalized"]

# %%
from nltk.stem import PorterStemmer
porter = PorterStemmer()

for word in words:
    print(word + "--->"+ porter.stem(word))
# Out:
# eating--->eat
# eats--->eat
# eaten--->eaten
# writing--->write
# writes--->write
# programming--->program
# programs--->program
# history--->histori
# finally--->final
# finalized--->final

# %%
porter.stem("congratulation")
# Out:
# 'congratul'

# %%
from nltk.stem import RegexpStemmer
regstemmer = RegexpStemmer('ing$|able$|s$|e$',min=4)

regstemmer.stem('eating')
# Out:
# 'eat'

# %%
regstemmer.stem('eatable')
# Out:
# 'eat'
